# %% [markdown]
# # Week 0 - Problem Set
#
# Practice what you learnt about the fundamentals of Machine Learning with these problems.

# %% [markdown]
# __1. In a markdown block, create an IPO (Input-Process-Output) table for a traditional algorithm that converts Celsius to Fahrenheit.__
#
# Hint: The formula is `F = (C × 9/5) + 32`

# %% [markdown]
# | Input | Process | Output |
# | ----- | ------- | ------ |
# |Celcius | Fahrenheit = (Celcius * 9/5) + 32 | Fahrenheit |

# %% [markdown]
# __2. In a markdown block, create an IPO table for a machine learning model that predicts temperature conversion. How would this differ from the traditional algorithm?__

# %% [markdown]
# | Input | Process | Output |
# | - | - | - |
# | Celsius (Feature) | Black box | Fahrenheit (Target) |
#
# The Process isn't determined via the programmer but rather generated by the model and thus is used to predict the target variable.

# %% [markdown]
# __3. Explain in your own words what a "black box" means in the context of machine learning. Why might this be a problem?__

# %% [markdown]
# Black box is the algorithm generated by the machine that is used to create a trend or connection between two variables. This algorithm can't be identified by programmers as the machine constantly adjusts the algorithm, making it hard for programmers to understand/interpret the algorithm. The only way to optimise this issue is to change the model.

# %% [markdown]
# __4. A company wants to build a machine learning model to predict which job applicants to interview. They plan to train it on 5 years of historical hiring data. Identify TWO potential sources of bias in this approach.__

# %% [markdown]
# 1. Job applicants have different personalities and qualities that may be undermined by the model
# 2. Not enough personnel were hired during this time period to give an accurate measurement

# %% [markdown]
# __5. Match each ethical principle with its description:__
#
# | Principle | Description |
# |-----------|-------------|
# | A. Fairness | 1. Model treats all groups equitably |
# | B. Transparency | 2. Decisions can be explained and understood |
# | C. Accountability  | 3. Someone is responsible for the model's outcomes |
# | D. Privacy | 4. Personal information is protected |

# %% [markdown]
# __6. Look at the code below. Explain why the ML model doesn't give exactly 6 as the answer, even though 4 + 2 = 6.__

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Training data
X = np.array([[1, 1], [2, 2], [3, 1], [5, 3]])
y = np.array([2, 4, 4, 8])

model = LinearRegression()
model.fit(X, y)

prediction = model.predict([[4, 2]])[0]
print(f"ML Model says 4 + 2 = {prediction:.4f}")
print(f"Actual answer: 4 + 2 = 6")

# %% [markdown]
# The line isn't fit and has bad intuition due to the fact that it's got limited data and is vulnerable to noise. The model is only able to learn off the lack of data thus can't create an accurate fit due to the training data. Meaning that there will be some loss amongst the predicted data.

# %% [markdown]
# __7. A facial recognition system is trained primarily on images of people with light skin. What type of bias is this, and what problems might it cause?__

# %% [markdown]
# There's an ethical issue where the model is essentially useless to other skin types as it was trained primarily light skin types. If it attempted to identify the target based off of a new skin type, it would heavily miss predict causing issues.

# %% [markdown]
# __8. Consider the following scenario:__
#
# A hospital uses a machine learning model to predict which patients need urgent care. The model was trained on historical data where patients from wealthier areas received more tests and therefore had more documented health issues.
#
# a) What type of bias might this model have?
#
#     The model will have sampling bias as majority of patients in wealthier areas may have had more tests in the past, thus if someone who may not have had such a good health record came in the model may miss identify. The model also won't be able to take into account the severity of the situation as it ignores face value or sudden occurrences.
#
# b) How might this affect patients from less wealthy areas?
#
#     Patients from less wealthier areas who may not have a decorated medical record, will get misdiagnosed losing the attention required, potentially dying.
#
# c) What ethical principle is being violated?
#
#     The principle of fairness, as not all groups are being treated equally.

# %% [markdown]
# __9. Complete the table comparing Traditional Programming and Machine Learning:__
#
# | Aspect | Traditional Programming | Machine Learning |
# |--------|------------------------|------------------|
# | How rules are created | Written by humans | Written by machine |
# | Outputs | Deterministic | Vary |
# | Can improve without reprogramming | No | Yes |
# | Transparency | Code | Often a black box |
# | Best for | Problems with clear rules | Complex issues or Large datasets |

# %% [markdown]
# __10. Read the following case study and answer the questions:__
#
# ### Case Study: Predictive Policing
#
# A city implements a machine learning system to predict where crimes are likely to occur. The system is trained on historical arrest data from the past 10 years. Police are then sent to patrol areas the model predicts will have high crime.
#
# **Questions:**
#
# a) If certain neighborhoods have historically been over-policed (more police presence leading to more arrests), how might this affect the model's predictions?
#
# The neighborhoods will receive unnecessary police attention, taking from other areas that may need it.
#
# b) Could this create a feedback loop? Explain how.
#
# The model should be able to adapt as when police are sent and crime lowers the attention for that area will reasserted elsewhere and this will continue indefinitely.
#
# c) What questions should be asked before deploying such a system?
#
# Is the timeframe appropriate allowing for an accurate distribution and will the model be able to assess noise accurately, allowing for police to be sent for patrol if an area suddenly spikes in crime.
#
# d) Who should be accountable if the system leads to unfair outcomes?
#
# The programmers as they chose the features that model uses to assess the risk of each area, thus where police should be placed for patrol.

# %% [markdown]
# __11. EXTENSION: Research one real-world example of bias in a machine learning system (not mentioned in the lesson). Write a short paragraph describing:__
#
# - What the system was designed to do
# - What bias was discovered
# - What the consequences were
# - How it could have been prevented
