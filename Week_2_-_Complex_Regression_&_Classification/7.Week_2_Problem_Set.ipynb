# %% [markdown]
# # Week 2 - Problem Set
#
# Practice what you learnt today with these problems; I will share the answers on Monday before the next workshop.

# %%
# Run the dependencies before you begin
import numpy as np
import matplotlib.pyplot as plt
from utils_common import generate_data

plt.style.use('ggplot')

# %% [markdown]
# **1. Using MD syntax, create a table of the two regression algorithms we have covered so far with the following headings.**
#
# - Algorythm
# - Regression or Classification
# - Popular uses

# %% [markdown]
# - Algorithm:
#     Logistic and Linear Regression are both two separate algorithms that utilize supervised learning models in order to predict targets. Linear Regression aims at predicting continuous target values whilst Logistic Regression predicts probabilities in order to classify and differ classes.
#
# - Regression/Classification:
#     Regression is a model that utilizes numerical features in order to predict continuous target variables.
#     Classification is a model that utilizes labels and uses specified data of features in order to predict categorical label
#
# - Popular uses:

# %% [markdown]
# **2. In a markdown block, outline why more than 3 degrees of polynomial expression are not recommended in Machine Learning.**

# %% [markdown]
# Polynomial expressions beyond 3 lead to overfitting of a model in Machine Learning. As high degrees create a model that's too fitted to training data and will not be able to predict new inputted data accurately

# %% [markdown]
# **3. Modify the code block below to label the two categories, apply a colour to each category, enable the legend, add a title "Logistic Data," and label the X & Y Axis with "Feature" and "Target."**
#
# | Category | Label |
# | --- | --- |
# | 0 | Australia |
# | 1 | New Zealand |

# %%
# Linear Regression For Classification
m = generate_data(20, 50, 0, 0, 300, 0.8)
n = generate_data(0, 30, 1, 1, 300, 0.8)
plt.scatter(m[0], m[1], c='r')
plt.scatter(n[0], n[1], c='r')
plt.title("Logistic Data")
plt.xlabel("Feature")
plt.ylabel("Target")
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_9779/2211226582.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# **4. In a markdown block, outline why Linear Regression is not a good machine learning model for classification.**

# %% [markdown]
# If Linear Regression was used for this dataset, there would be too much prediction error as a linear pattern is too simplistic generalising the trend and underfitting the data.

# %% [markdown]
# __5. In a markdown block, outline the machine learning Logistic Regression algorithm.__

# %% [markdown]
# Logistic Regression is a supervised ML model that utilises the sigmoid function and polynomial equations to more accurately fit datasets. By having two separate classes and a curved decision boundary, data can be split into two separate categories where it is then analyzed by its probability of not being a certain class which allows for the programmer to determine the label for the individual data point.

# %% [markdown]
# **6. Using the [OOP Logistic Regression](4.OOP_Logistic_Regression.ipynb) as an example, design, fit and evaluate an [Iris classification OOP implementation](6.OOP_Iris_Logistic_Regression.ipynb).**

# %% [markdown]
# __7. After completing Logistic Regression for the Iris data set (Q6), justify why you selected the features you did for your model.__
